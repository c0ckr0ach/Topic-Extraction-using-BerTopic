# %% [markdown]
# <a href="https://colab.research.google.com/github/c0ckr0ach/Topic-Extraction-using-BerTopic/blob/llama_api/topic_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import re
import nltk
from nltk import *
from nltk.corpus import stopwords

df = pd.read_csv('/content/drive/MyDrive/Datasets/bbc_news.csv')
df.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                          pubDate  \
# 0  Mon, 07 Mar 2022 08:01:56 GMT
# 1  Sun, 06 Mar 2022 22:49:58 GMT
# 2  Mon, 07 Mar 2022 00:14:42 GMT
# 3  Mon, 07 Mar 2022 00:05:40 GMT
# 4  Mon, 07 Mar 2022 08:15:53 GMT
#
#                                                guid  \
# 0  https://www.bbc.co.uk/news/world-europe-60638042
# 1  https://www.bbc.co.uk/news/world-europe-60641873
# 2      https://www.bbc.co.uk/news/business-60623941
# 3            https://www.bbc.co.uk/news/uk-60579079
# 4      https://www.bbc.co.uk/news/business-60642786
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/world-europe-606380...
# ...

# %%
df.shape
# Out:
# (42115, 5)

# %% [markdown]
# punkt: sentence

# %%
nltk.download(['punkt_tab', 'stopwords', 'wordnet'])
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **Preprocessing Steps**
# 1. URL removal
# 2. HTML tag removal
# 3. Hyphenated word split
# 4. Word Tokenization & stop word removal
# 5. Parts of speech tagging.
# 6. Lemmatization

# %%
def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'&amp;', 'and', text)
    text = re.sub(r'(\w+)-(\w+)', r'\1 \2', text)  #split hyphenated words
    text = re.sub(r'\b\d+\b', '', text)  #remove dates
    words = word_tokenize(text)
    words = [
        word for word in words
        if (len(word) > 2) and not word.isnumeric()
    ]
    words = [word.lower() for word in words]

    return " ".join(words)


df['combined_txt'] = df['title'] + " " + df['description']
df['processed'] = df['combined_txt'].apply(preprocess_text)
df = df[df['processed'].str.len() > 30].reset_index(drop=True)
df[['processed']].to_csv('preprocessed_bbc_news.csv', index=False)

# %% [markdown]
# **Processed Dataframe**

# %%
df.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                          pubDate  \
# 0  Mon, 07 Mar 2022 08:01:56 GMT
# 1  Sun, 06 Mar 2022 22:49:58 GMT
# 2  Mon, 07 Mar 2022 00:14:42 GMT
# 3  Mon, 07 Mar 2022 00:05:40 GMT
# 4  Mon, 07 Mar 2022 08:15:53 GMT
#
#                                                guid  \
# 0  https://www.bbc.co.uk/news/world-europe-60638042
# 1  https://www.bbc.co.uk/news/world-europe-60641873
# 2      https://www.bbc.co.uk/news/business-60623941
# 3            https://www.bbc.co.uk/news/uk-60579079
# 4      https://www.bbc.co.uk/news/business-60642786
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/world-europe-606380...
# ...

# %%
# !pip install bertopic

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from bertopic.representation import MaximalMarginalRelevance
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
import os

output_dir = 'BERT_model'
os.makedirs(output_dir, exist_ok = True)

# %% [markdown]
# **Sentence Transformer:** Pretrained transformer model that maps each input text into a fixed length vector.
# **Dimensionality Reduction(UMAP):** Projects the high dimensional embeddings to a lower dimensional space(5 here).
# **Clustering using HDBSCAN:** Finds densely connected groups in the dataset and labels low density points as noise. Each formed cluster represents a topic.
# **CountVectorizer for term extraction:** Turns corpus into term-document matrix to identify the most frequent terms per topic.
#
# **BERTopic**
# It is a framework that ties together the above four. Goal is to produce human readable topics from the corpus without manually specifying the amount of topics in advance.

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(df['processed'].tolist(),
                                    show_progress_bar=True)

umap_model = UMAP(n_neighbors=15,
                  n_components=5,
                  min_dist=0.0,
                  metric='cosine')

hdbscan_model = HDBSCAN(min_cluster_size=80,
                        cluster_selection_method='eom',
                        prediction_data=True)

vectorizer_model = CountVectorizer(stop_words="english",
                                   min_df=2, ngram_range=(1, 2))

representation_model = MaximalMarginalRelevance(diversity=0.5)

topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    representation_model= representation_model,
    top_n_words=10,
    language='english',
    calculate_probabilities=True,
    verbose=True
)

topics, probs = topic_model.fit_transform(df['processed'])

topic_model.save(os.path.join(output_dir,"bertopic_model"))

topic_info = topic_model.get_topic_info() #gets [topic, count, name, representation]
topic_info.to_csv(os.path.join(output_dir, 'topic_info.csv'), index=False)

representative_docs = topic_model.get_representative_docs()
pd.DataFrame(representative_docs.items(),
             columns=['Topic', 'Representative_Docs']).to_csv(os.path.join(output_dir,'representative_docs.csv'), index=False) #topic id to its top example(representative) documents

print("topic modeling complete")
print(f"topics created: {len(topic_info)}")
# Out:
# Batches:   0%|          | 0/1317 [00:00<?, ?it/s]
# 2025-08-19 19:06:57,666 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/1317 [00:00<?, ?it/s]
# 2025-08-19 19:13:44,940 - BERTopic - Embedding - Completed ✓
# 2025-08-19 19:13:44,941 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-08-19 19:14:07,866 - BERTopic - Dimensionality - Completed ✓
# 2025-08-19 19:14:07,867 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-08-19 19:14:23,101 - BERTopic - Cluster - Completed ✓
# 2025-08-19 19:14:23,109 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-08-19 19:14:29,403 - BERTopic - Representation - Completed ✓
# ...

# %%
topic_info
# Out:
#     Topic  Count                                               Name  \
# 0      -1  12629                        -1_says_bbc_election_labour
# 1       0   6211                             0_cup_world_final_euro
# 2       1   2933                       1_murder_year old_woman_died
# 3       2   2677               2_ukraine war_zelensky_says_mariupol
# 4       3   1262     3_king charles_coronation_prince harry_funeral
# ..    ...    ...                                                ...
# 61     60     97      60_lucy letby_serial_nursery_attempted murder
# 62     61     92      61_sewage_thames water_spills_water companies
# 63     62     89  62_northern ireland_northern_protocol_friday a...
# 64     63     85             63_electric cars_drivers_rac_fuel duty
# 65     64     80          64_south pole_space station_capsule_india
#
#                                        Representation  \
# 0   [says, bbc, election, labour, papers, tax, tor...
# ...

# %%
df = pd.DataFrame({'topic': topics,'Documents': df['processed']})

# %%
df
# Out:
#        topic                                          Documents
# 0          2  ukraine angry zelensky vows punish russian atr...
# 1          2  war ukraine taking cover town under attack jer...
# 2          2  ukraine war catastrophic for global food one t...
# 3         -1  manchester arena bombing saffie roussos parent...
# 4          2  ukraine conflict oil price soars highest level...
# ...      ...                                                ...
# 42110      0  highlights wales make history dublin watch hig...
# 42111     -1  gang jailed over 200m cocaine banana boxes mor...
# 42112     -1  scottish budget presents huge challenges for s...
# 42113      0  celebrations wales make history qualifying for...
# 42114     49  school tells muslim girls not safe for them th...
#
# [42115 rows x 2 columns]

# %%
df.to_csv('bbc_news_topics.csv', index=False)

# %% [markdown]
# **Model Evaluation**
# **1. Bar Charts:**
# Bars represents top 5 words from each topic.
# Length of each bar is the c-TF-IDF score/weight, shows the word's importance or score in that topic.
# Higher score = more representative of this topic compared to others.
#
# c-TF-IDF: class based TF-IDF score, where instead of treating each document, we consider the Topic(cluster of documents) as one large document
#
# **Intertopic Distance Map**
# Shows all topics discovered in a plane.
# Each bubble represents one topic, size of each bubble = how many docs belong to the topic.
# Distance between bubbles indicate how similar topics are to each other.
# The more closer something is, the more semantically similar they are.

# %%
topic_model.visualize_barchart(top_n_topics=10).show()

topic_model.visualize_topics().show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install transformers

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
model_name = "HuggingFaceTB/SmolLM2-135M-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/861 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
df = pd.read_csv("/content/BERT_model/topic_info.csv", header=None)
topics = df.iloc[2:12, 2].dropna().astype(str).tolist()

# %%
def make_prompt(topic):
    return (
        f"generate 5 questions about the topic:\n"
        f"topic: {topic}\n"
        f"1."
    )

# %%
def generate_questions(topic, max_length=150):
    prompt = make_prompt(topic)
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(
        **inputs,
        max_new_tokens=max_length,
        do_sample=False,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
    )
    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    lines = [line.strip() for line in text.split('\n') if line.strip()]
    return lines[1:6]

# %%
for topic in topics:
    qs = generate_questions(topic)
    print(f"Topic: {topic}")
    for q in qs:
        print("  -", q)
    print()
# Out:
# Topic: 0_world cup_final_liverpool_women
#   - topic: 0_world cup_final_liverpool_women
#   - 1. What is the name of the tournament?
#   - 2. What is the name of the team that won the tournament?
#   - 3. What is the name of the team that lost the tournament?
#   - 4. What is the name of the team that won the tournament?
#
# Topic: 1_ukraine war_kyiv_zelensky_nato
#   - topic: 1_ukraine war_kyiv_zelensky_nato
#   - 1. What was the main cause of the war?
#   - 2. What was the main cause of the war?
#   - 3. What was the main cause of the war?
#   - 4. What was the main cause of the war?
#
# Topic: 2_police_murder_year old_died
#   - topic: 2_police_murder_year old_died
#   - 1. What was the name of the person who was killed in the police murder?
#   - 2. Who was the victim?
#   - 3. What was the crime scene?
#   - 4. What was the time of the murder?
#
# Topic: 3_king charles_royal_queen elizabeth_princess
#   - topic: 3_king charles_royal_queen elizabeth_princess
# ...
